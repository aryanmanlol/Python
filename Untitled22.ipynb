# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanmanlol/Python/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.column=["golu","cutu","daddy","indori","patootu"]

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
zonea={"target":70000,"sales":50000}
zoneb={"target":60000,"sales":40000}
zonec={"target":90000,"sales":80000}
zoned={"target":80000,"sales":30000}
final=[zonea,zoneb,zonec,zoned]
df=pd.DataFrame(final)

# %%
df
# Out:
#    target  sales
# 0   70000  50000
# 1   60000  40000
# 2   90000  80000
# 3   80000  30000

# %%
df.index=["zonea","zoneb","zonec","zoned"]

# %%
df
# Out:
#        target  sales
# zonea   70000  50000
# zoneb   60000  40000
# zonec   90000  80000
# zoned   80000  30000

# %%
n=int(input("n: "))
for i in range(2,n):
  if n%i==0:
    print("it is not a prime no.")
    break
  else:
    print("prime hai")
    break
# Out:
# n: 7
# prime hai

# %%
import numpy as np

# %%
from numpy import random

# %%
random=np.random.randint(1,100,size=8)

# %%
random
# Out:
# array([64, 31, 22, 62, 51, 99, 92,  8])

# %%
arr=random.reshape(2,2,-1)

# %%
arr
# Out:
# array([[[95, 65],
#         [87, 47]],
#
#        [[10, 66],
#         [62, 22]]])

# %%
arr[1:2]
# Out:
# array([[51, 99, 92,  8]])

# %%
arr[0::,1:4:2]
# Out:
# array([[31, 62],
#        [99,  8]])

# %%
a=input("enter string:")
a[0::2]
# Out:
# enter string:ektucutu
# 'etct'

# %%
n=int(input("enter:"))
strong=0
temp=n


while n>0:
  fact=1
  e=n%10
  n=n//10
  while e>0:
    fact=fact*e
    e-=1
  strong+=fact
print(strong)

if strong==temp:
  print("its a strong number")
# Out:
# enter:890
# 403201

# %%
# Out:
# 56

# %%
a=int(input("a :"))
a=str(a)
print(a[::-1])
# Out:
# a :1234
# 4321
