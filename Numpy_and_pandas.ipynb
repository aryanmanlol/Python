# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanmanlol/Python/blob/main/Numpy_and_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from numpy import random

# %%
#1

# %%
a=random.randint(10,100,size=(3,5,3))
a
# Out:
# array([[[68, 18, 91],
#         [25, 53, 69],
#         [55, 47, 98],
#         [18, 39, 22],
#         [77, 89, 61]],
#
#        [[63, 44, 13],
#         [80, 46, 30],
#         [36, 26, 17],
#         [66, 78, 23],
#         [87, 54, 94]],
#
#        [[28, 21, 85],
#         [57, 48, 54],
#         [66, 63, 97],
#         [26, 98, 52],
#         [18, 67, 84]]])

# %%
#2
s=int(input("size of list"))
list=[]
for i in range(0,s):
  l=int(input("enter elements"))
  list.append(l)

a=np.array(list)
newarr=a.reshape(2,-1)
# Out:
# size of list6
# enter elements1
# enter elements2
# enter elements3
# enter elements4
# enter elements5
# enter elements6

# %%
print(newarr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
p=int(input("lower range"))
q=int(input("higher range"))
m=int(input("enter rows"))
n=int(input("enter columns"))
random=random.randint(p,q,size=(m,n))
print(random)
# Out:
# lower range3
# higher range80
# enter rows4
# enter columns5
# [[64  3 23 32 16]
#  [14 16 36 77 41]
#  [37 24 19 42 40]
#  [33 18 20 51 14]]

# %%
print(random.ndim)
# Out:
# 2

# %%
print(random.size)
# Out:
# 20

# %%
arr=random.reshape(5,-1)

# %%
arr
# Out:
# array([[64,  3, 23, 32],
#        [16, 14, 16, 36],
#        [77, 41, 37, 24],
#        [19, 42, 40, 33],
#        [18, 20, 51, 14]])

# %%
array=np.array([[2,3,4,5,6,7],[3,90,10,14,7,8]])
array[1,1:4]
# Out:
# array([90, 10, 14])

# %%
arr=np.sort(array)

# %%
arr
# Out:
# array([[ 2,  3,  4,  5,  6,  7],
#        [ 3,  7,  8, 10, 14, 90]])

# %%
import pandas as pd

# %%
dist={1:["golu","boob"],2:["ektu",0],3:["patootu",0]}
d=pd.DataFrame(dist)
print(d)
# Out:
#       1     2        3
# 0  golu  ektu  patootu
# 1  boob     0        0

# %%
list1=[2,3,4,5,6,7]
list2=[4,5,6,7,8,9]
list3=[10,20,30,40,50,60]
df=pd.DataFrame([list1,list2,list3])
df
# Out:
#     0   1   2   3   4   5
# 0   2   3   4   5   6   7
# 1   4   5   6   7   8   9
# 2  10  20  30  40  50  60
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df[1].plot(kind='hist', bins=20, title=1)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df[2].plot(kind='hist', bins=20, title=2)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df[3].plot(kind='hist', bins=20, title=3)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-6db04c082d11> in <cell line: 1>()
# ----> 1 iris.csv
#
# NameError: name 'iris' is not defined
